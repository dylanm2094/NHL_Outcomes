# %%
import pandas as pd
from keras.models import Sequential, model_from_json
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv("final_df.csv")
cols = [0]
df.drop(df.columns[cols],axis=1,inplace=True)
df
# Out:
#        Home   ML  Puck Line     PL  Line Mvmt  net_goals  Win  Win_PL
# 0         0 -105        1.5 -305.0          0          0    1       1
# 1         1 -115       -1.5  250.0          0          0    0       0
# 2         0  165        1.5 -180.0          0          0    0       1
# 3         1 -185       -1.5  155.0        -10          0    1       0
# 4         0  130        1.5 -240.0        -29          0    1       1
# ...     ...  ...        ...    ...        ...        ...  ...     ...
# 13325     1 -160       -1.5  176.0          5        164    0       0
# 13326     0  105        1.5 -280.0         -5        163    1       1
# 13327     1 -115       -1.5  230.0         -5        118    0       0
# 13328     0  155        1.5 -183.0         -4        114    1       1
# 13329     1 -170       -1.5  159.0         -5        167    0       0
#
# [13330 rows x 8 columns]

# %%
target = df["Win_PL"]
target_names = ["loss", "win"]

# %%
data = df.drop(columns=['Win', 'Win_PL'],axis=1)
feature_names = data.columns

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.3, random_state=42)

# %%
y_train_categorical = to_categorical(y_train)
y_test_categorical = to_categorical(y_test)

# %%
def build_model():
    # create model
    model = Sequential()
    model.add(Dense(units=18, activation='relu', input_dim=6))
    model.add(Dense(units=9, activation='relu'))
    model.add(Dense(units=2, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

def save_model(model):
    # saving model
    json_model = model.to_json()
    open('PL_model_architecture.json', 'w').write(json_model)
    # saving weights
    model.save_weights('PL_model_weights.h5', overwrite=True)

# %%
# build
model = build_model()
model.fit(X_train, y_train_categorical, epochs=100, shuffle=True, verbose=2)
model_loss, model_accuracy = model.evaluate(X_test, y_test_categorical, verbose=2)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")

# save
save_model(model)
# Out:
# Epoch 1/100
#  - 1s - loss: 3.0282 - accuracy: 0.5691
# Epoch 2/100
#  - 1s - loss: 0.9814 - accuracy: 0.5925
# Epoch 3/100
#  - 0s - loss: 0.8337 - accuracy: 0.6052
# Epoch 4/100
#  - 0s - loss: 0.7787 - accuracy: 0.6086
# Epoch 5/100
#  - 0s - loss: 0.7332 - accuracy: 0.6249
# Epoch 6/100
#  - 0s - loss: 0.7263 - accuracy: 0.6195
# Epoch 7/100
#  - 0s - loss: 0.7113 - accuracy: 0.6253
# Epoch 8/100
#  - 1s - loss: 0.7006 - accuracy: 0.6275
# Epoch 9/100
#  - 1s - loss: 0.6938 - accuracy: 0.6294
# Epoch 10/100
#  - 1s - loss: 0.6832 - accuracy: 0.6351
# Epoch 11/100
#  - 1s - loss: 0.6839 - accuracy: 0.6303
# Epoch 12/100
#  - 1s - loss: 0.6871 - accuracy: 0.6310
# Epoch 13/100
#  - 1s - loss: 0.6770 - accuracy: 0.6370
# Epoch 14/100
#  - 1s - loss: 0.6884 - accuracy: 0.6252
# Epoch 15/100
#  - 1s - loss: 0.6750 - accuracy: 0.6387
# Epoch 16/100
#  - 1s - loss: 0.6661 - accuracy: 0.6425
# Epoch 17/100
#  - 1s - loss: 0.6703 - accuracy: 0.6417
# Epoch 18/100
#  - 1s - loss: 0.6704 - accuracy: 0.6364
# Epoch 19/100
#  - 1s - loss: 0.6766 - accuracy: 0.6350
# Epoch 20/100
#  - 1s - loss: 0.6739 - accuracy: 0.6340
# Epoch 21/100
#  - 1s - loss: 0.6719 - accuracy: 0.6399
# Epoch 22/100
#  - 1s - loss: 0.6604 - accuracy: 0.6439
# Epoch 23/100
#  - 1s - loss: 0.6550 - accuracy: 0.6466
# Epoch 24/100
#  - 0s - loss: 0.6595 - accuracy: 0.6446
# Epoch 25/100
#  - 0s - loss: 0.6641 - accuracy: 0.6402
# Epoch 26/100
#  - 0s - loss: 0.6681 - accuracy: 0.6332
# Epoch 27/100
#  - 0s - loss: 0.6581 - accuracy: 0.6464
# Epoch 28/100
#  - 1s - loss: 0.6592 - accuracy: 0.6477
# Epoch 29/100
#  - 1s - loss: 0.6528 - accuracy: 0.6514
# Epoch 30/100
#  - 1s - loss: 0.6536 - accuracy: 0.6535
# Epoch 31/100
#  - 1s - loss: 0.6521 - accuracy: 0.6526
# Epoch 32/100
#  - 1s - loss: 0.6502 - accuracy: 0.6519
# Epoch 33/100
#  - 1s - loss: 0.6504 - accuracy: 0.6518
# Epoch 34/100
#  - 0s - loss: 0.6593 - accuracy: 0.6473
# Epoch 35/100
#  - 0s - loss: 0.6473 - accuracy: 0.6561
# Epoch 36/100
#  - 0s - loss: 0.6488 - accuracy: 0.6547
# Epoch 37/100
#  - 1s - loss: 0.6518 - accuracy: 0.6533
# Epoch 38/100
#  - 1s - loss: 0.6516 - accuracy: 0.6500
# Epoch 39/100
#  - 1s - loss: 0.6498 - accuracy: 0.6547
# Epoch 40/100
#  - 1s - loss: 0.6467 - accuracy: 0.6535
# Epoch 41/100
#  - 1s - loss: 0.6487 - accuracy: 0.6561
# Epoch 42/100
#  - 1s - loss: 0.6512 - accuracy: 0.6545
# Epoch 43/100
#  - 1s - loss: 0.6510 - accuracy: 0.6487
# Epoch 44/100
#  - 1s - loss: 0.6433 - accuracy: 0.6624
# Epoch 45/100
#  - 1s - loss: 0.6426 - accuracy: 0.6545
# Epoch 46/100
#  - 1s - loss: 0.6417 - accuracy: 0.6604
# Epoch 47/100
#  - 1s - loss: 0.6425 - accuracy: 0.6598
# Epoch 48/100
#  - 0s - loss: 0.6384 - accuracy: 0.6623
# Epoch 49/100
#  - 0s - loss: 0.6432 - accuracy: 0.6575
# Epoch 50/100
#  - 0s - loss: 0.6398 - accuracy: 0.6590
# Epoch 51/100
#  - 1s - loss: 0.6378 - accuracy: 0.6627
# Epoch 52/100
#  - 1s - loss: 0.6403 - accuracy: 0.6631
# Epoch 53/100
#  - 1s - loss: 0.6403 - accuracy: 0.6626
# Epoch 54/100
#  - 1s - loss: 0.6389 - accuracy: 0.6632
# Epoch 55/100
#  - 1s - loss: 0.6390 - accuracy: 0.6652
# Epoch 56/100
#  - 1s - loss: 0.6388 - accuracy: 0.6609
# Epoch 57/100
#  - 1s - loss: 0.6353 - accuracy: 0.6664
# Epoch 58/100
#  - 1s - loss: 0.6394 - accuracy: 0.6596
# Epoch 59/100
#  - 1s - loss: 0.6358 - accuracy: 0.6638
# Epoch 60/100
#  - 1s - loss: 0.6348 - accuracy: 0.6662
# Epoch 61/100
#  - 1s - loss: 0.6341 - accuracy: 0.6677
# Epoch 62/100
#  - 1s - loss: 0.6330 - accuracy: 0.6653
# Epoch 63/100
#  - 1s - loss: 0.6343 - accuracy: 0.6641
# Epoch 64/100
#  - 1s - loss: 0.6337 - accuracy: 0.6664
# Epoch 65/100
#  - 1s - loss: 0.6337 - accuracy: 0.6686
# Epoch 66/100
#  - 1s - loss: 0.6340 - accuracy: 0.6664
# Epoch 67/100
#  - 1s - loss: 0.6326 - accuracy: 0.6665
# Epoch 68/100
#  - 1s - loss: 0.6340 - accuracy: 0.6661
# Epoch 69/100
#  - 1s - loss: 0.6338 - accuracy: 0.6649
# Epoch 70/100
#  - 1s - loss: 0.6321 - accuracy: 0.6680
# Epoch 71/100
#  - 1s - loss: 0.6324 - accuracy: 0.6687
# Epoch 72/100
#  - 1s - loss: 0.6324 - accuracy: 0.6673
# Epoch 73/100
#  - 1s - loss: 0.6322 - accuracy: 0.6684
# Epoch 74/100
#  - 1s - loss: 0.6332 - accuracy: 0.6649
# Epoch 75/100
#  - 1s - loss: 0.6340 - accuracy: 0.6663
# Epoch 76/100
#  - 1s - loss: 0.6336 - accuracy: 0.6685
# Epoch 77/100
#  - 1s - loss: 0.6333 - accuracy: 0.6662
# Epoch 78/100
#  - 1s - loss: 0.6322 - accuracy: 0.6665
# Epoch 79/100
#  - 1s - loss: 0.6331 - accuracy: 0.6671
# Epoch 80/100
#  - 1s - loss: 0.6319 - accuracy: 0.6669
# Epoch 81/100
#  - 1s - loss: 0.6340 - accuracy: 0.6660
# Epoch 82/100
#  - 1s - loss: 0.6341 - accuracy: 0.6662
# Epoch 83/100
#  - 1s - loss: 0.6320 - accuracy: 0.6671
# Epoch 84/100
#  - 1s - loss: 0.6325 - accuracy: 0.6676
# Epoch 85/100
#  - 1s - loss: 0.6318 - accuracy: 0.6673
# Epoch 86/100
#  - 1s - loss: 0.6327 - accuracy: 0.6677
# Epoch 87/100
#  - 1s - loss: 0.6323 - accuracy: 0.6682
# Epoch 88/100
#  - 1s - loss: 0.6318 - accuracy: 0.6686
# Epoch 89/100
#  - 1s - loss: 0.6324 - accuracy: 0.6668
# Epoch 90/100
#  - 1s - loss: 0.6309 - accuracy: 0.6681
# Epoch 91/100
#  - 1s - loss: 0.6322 - accuracy: 0.6668
# Epoch 92/100
#  - 0s - loss: 0.6322 - accuracy: 0.6661
# Epoch 93/100
#  - 0s - loss: 0.6309 - accuracy: 0.6680
# Epoch 94/100
#  - 0s - loss: 0.6320 - accuracy: 0.6671
# Epoch 95/100
#  - 1s - loss: 0.6321 - accuracy: 0.6681
# Epoch 96/100
#  - 1s - loss: 0.6310 - accuracy: 0.6690
# Epoch 97/100
#  - 0s - loss: 0.6313 - accuracy: 0.6672
# Epoch 98/100
#  - 1s - loss: 0.6323 - accuracy: 0.6662
# Epoch 99/100
#  - 1s - loss: 0.6313 - accuracy: 0.6687
# Epoch 100/100
#  - 1s - loss: 0.6312 - accuracy: 0.6676
# Deep Neural Network - Loss: 0.6409461802618299, Accuracy: 0.6591647863388062
