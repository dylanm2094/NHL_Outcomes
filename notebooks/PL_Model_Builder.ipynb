# %%
import pandas as pd
from keras.models import Sequential, model_from_json
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv("final_df.csv")
cols = [0]
df.drop(df.columns[cols],axis=1,inplace=True)
df
# Out:
#        Home   ML  Puck Line     PL  Line Mvmt  net_goals  Win  Win_PL
# 0         0 -105        1.5 -305.0          0          0    1       1
# 1         1 -115       -1.5  250.0          0          0    0       0
# 2         0  165        1.5 -180.0          0          0    0       1
# 3         1 -185       -1.5  155.0        -10          0    1       0
# 4         0  130        1.5 -240.0        -29          0    1       1
# ...     ...  ...        ...    ...        ...        ...  ...     ...
# 15489     1 -146       -1.5  170.0        -19         45    1       0
# 15490     0  145        1.5 -180.0         -5        -51    0       1
# 15491     1 -160       -1.5  160.0          0        -35    1       0
# 15492     0 -200       -1.5  115.0         23         30    1       1
# 15493     1  180        1.5 -135.0        -28        -37    0       0
#
# [15494 rows x 8 columns]

# %%
target = df["Win_PL"]
target_names = ["loss", "win"]

# %%
data = df.drop(columns=['Win', 'Win_PL'],axis=1)
feature_names = data.columns

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.3, random_state=42)

# %%
y_train_categorical = to_categorical(y_train)
y_test_categorical = to_categorical(y_test)

# %%
def build_model():
    # create model
    model = Sequential()
    model.add(Dense(units=18, activation='relu', input_dim=6))
    model.add(Dense(units=9, activation='relu'))
    model.add(Dense(units=2, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

def save_model(model):
    # saving model
    json_model = model.to_json()
    open('PL_model_architecture.json', 'w').write(json_model)
    # saving weights
    model.save_weights('PL_model_weights.h5', overwrite=True)

# %%
# build
model = build_model()
model.fit(X_train, y_train_categorical, epochs=100, shuffle=True, verbose=2)
model_loss, model_accuracy = model.evaluate(X_test, y_test_categorical, verbose=2)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/100
#  - 1s - loss: 1.6530 - accuracy: 0.5735
# Epoch 2/100
#  - 1s - loss: 0.8551 - accuracy: 0.6030
# Epoch 3/100
#  - 1s - loss: 0.7887 - accuracy: 0.6067
# Epoch 4/100
#  - 1s - loss: 0.7415 - accuracy: 0.6150
# Epoch 5/100
#  - 1s - loss: 0.7145 - accuracy: 0.6192
# Epoch 6/100
#  - 1s - loss: 0.7061 - accuracy: 0.6211
# Epoch 7/100
#  - 1s - loss: 0.6913 - accuracy: 0.6298
# Epoch 8/100
#  - 1s - loss: 0.6834 - accuracy: 0.6277
# Epoch 9/100
#  - 1s - loss: 0.6783 - accuracy: 0.6336
# Epoch 10/100
#  - 1s - loss: 0.6858 - accuracy: 0.6308
# Epoch 11/100
#  - 1s - loss: 0.6853 - accuracy: 0.6281
# Epoch 12/100
#  - 1s - loss: 0.6725 - accuracy: 0.6323
# Epoch 13/100
#  - 1s - loss: 0.6759 - accuracy: 0.6333
# Epoch 14/100
#  - 1s - loss: 0.6710 - accuracy: 0.6349
# Epoch 15/100
#  - 1s - loss: 0.6757 - accuracy: 0.6299
# Epoch 16/100
#  - 1s - loss: 0.6751 - accuracy: 0.6348
# Epoch 17/100
#  - 1s - loss: 0.6634 - accuracy: 0.6415
# Epoch 18/100
#  - 1s - loss: 0.6583 - accuracy: 0.6424
# Epoch 19/100
#  - 1s - loss: 0.6653 - accuracy: 0.6371
# Epoch 20/100
#  - 1s - loss: 0.6616 - accuracy: 0.6408
# Epoch 21/100
#  - 1s - loss: 0.6606 - accuracy: 0.6473
# Epoch 22/100
#  - 1s - loss: 0.6590 - accuracy: 0.6446
# Epoch 23/100
#  - 1s - loss: 0.6634 - accuracy: 0.6464
# Epoch 24/100
#  - 1s - loss: 0.6572 - accuracy: 0.6489
# Epoch 25/100
#  - 1s - loss: 0.6553 - accuracy: 0.6490
# Epoch 26/100
#  - 1s - loss: 0.6516 - accuracy: 0.6538
# Epoch 27/100
#  - 1s - loss: 0.6528 - accuracy: 0.6510
# Epoch 28/100
#  - 1s - loss: 0.6476 - accuracy: 0.6561
# Epoch 29/100
#  - 1s - loss: 0.6482 - accuracy: 0.6550
# Epoch 30/100
#  - 1s - loss: 0.6510 - accuracy: 0.6511
# Epoch 31/100
#  - 1s - loss: 0.6459 - accuracy: 0.6552
# Epoch 32/100
#  - 1s - loss: 0.6472 - accuracy: 0.6533
# Epoch 33/100
#  - 1s - loss: 0.6454 - accuracy: 0.6554
# Epoch 34/100
#  - 1s - loss: 0.6469 - accuracy: 0.6542
# Epoch 35/100
#  - 1s - loss: 0.6446 - accuracy: 0.6566
# Epoch 36/100
#  - 1s - loss: 0.6423 - accuracy: 0.6550
# Epoch 37/100
#  - 1s - loss: 0.6435 - accuracy: 0.6531
# Epoch 38/100
#  - 1s - loss: 0.6455 - accuracy: 0.6557
# Epoch 39/100
#  - 1s - loss: 0.6415 - accuracy: 0.6573
# Epoch 40/100
#  - 1s - loss: 0.6417 - accuracy: 0.6553
# Epoch 41/100
#  - 1s - loss: 0.6406 - accuracy: 0.6572
# Epoch 42/100
#  - 1s - loss: 0.6393 - accuracy: 0.6590
# Epoch 43/100
#  - 1s - loss: 0.6405 - accuracy: 0.6583
# Epoch 44/100
#  - 1s - loss: 0.6414 - accuracy: 0.6560
# Epoch 45/100
#  - 1s - loss: 0.6398 - accuracy: 0.6589
# Epoch 46/100
#  - 1s - loss: 0.6382 - accuracy: 0.6599
# Epoch 47/100
#  - 1s - loss: 0.6383 - accuracy: 0.6595
# Epoch 48/100
#  - 1s - loss: 0.6396 - accuracy: 0.6580
# Epoch 49/100
#  - 1s - loss: 0.6374 - accuracy: 0.6590
# Epoch 50/100
#  - 1s - loss: 0.6378 - accuracy: 0.6588
# Epoch 51/100
#  - 1s - loss: 0.6378 - accuracy: 0.6598
# Epoch 52/100
#  - 1s - loss: 0.6387 - accuracy: 0.6598
# Epoch 53/100
#  - 1s - loss: 0.6378 - accuracy: 0.6602
# Epoch 54/100
#  - 1s - loss: 0.6377 - accuracy: 0.6589
# Epoch 55/100
#  - 1s - loss: 0.6381 - accuracy: 0.6584
# Epoch 56/100
#  - 1s - loss: 0.6373 - accuracy: 0.6596
# Epoch 57/100
#  - 1s - loss: 0.6367 - accuracy: 0.6586
# Epoch 58/100
#  - 1s - loss: 0.6362 - accuracy: 0.6599
# Epoch 59/100
#  - 1s - loss: 0.6363 - accuracy: 0.6612
# Epoch 60/100
#  - 1s - loss: 0.6365 - accuracy: 0.6595
# Epoch 61/100
#  - 1s - loss: 0.6360 - accuracy: 0.6602
# Epoch 62/100
#  - 1s - loss: 0.6357 - accuracy: 0.6600
# Epoch 63/100
#  - 1s - loss: 0.6357 - accuracy: 0.6608
# Epoch 64/100
#  - 1s - loss: 0.6359 - accuracy: 0.6595
# Epoch 65/100
#  - 1s - loss: 0.6365 - accuracy: 0.6598
# Epoch 66/100
#  - 1s - loss: 0.6362 - accuracy: 0.6605
# Epoch 67/100
#  - 1s - loss: 0.6353 - accuracy: 0.6606
# Epoch 68/100
#  - 1s - loss: 0.6369 - accuracy: 0.6601
# Epoch 69/100
#  - 1s - loss: 0.6353 - accuracy: 0.6607
# Epoch 70/100
#  - 1s - loss: 0.6358 - accuracy: 0.6602
# Epoch 71/100
#  - 1s - loss: 0.6362 - accuracy: 0.6601
# Epoch 72/100
#  - 1s - loss: 0.6355 - accuracy: 0.6605
# Epoch 73/100
#  - 1s - loss: 0.6353 - accuracy: 0.6602
# Epoch 74/100
#  - 1s - loss: 0.6353 - accuracy: 0.6590
# Epoch 75/100
#  - 1s - loss: 0.6361 - accuracy: 0.6586
# Epoch 76/100
#  - 1s - loss: 0.6365 - accuracy: 0.6590
# Epoch 77/100
#  - 1s - loss: 0.6354 - accuracy: 0.6607
# Epoch 78/100
#  - 1s - loss: 0.6346 - accuracy: 0.6610
# Epoch 79/100
#  - 1s - loss: 0.6358 - accuracy: 0.6611
# Epoch 80/100
#  - 1s - loss: 0.6360 - accuracy: 0.6605
# Epoch 81/100
#  - 1s - loss: 0.6355 - accuracy: 0.6604
# Epoch 82/100
#  - 1s - loss: 0.6359 - accuracy: 0.6612
# Epoch 83/100
#  - 1s - loss: 0.6346 - accuracy: 0.6595
# Epoch 84/100
#  - 1s - loss: 0.6349 - accuracy: 0.6602
# Epoch 85/100
#  - 1s - loss: 0.6352 - accuracy: 0.6613
# Epoch 86/100
#  - 1s - loss: 0.6355 - accuracy: 0.6623
# Epoch 87/100
#  - 1s - loss: 0.6351 - accuracy: 0.6599
# Epoch 88/100
#  - 1s - loss: 0.6347 - accuracy: 0.6614
# Epoch 89/100
#  - 1s - loss: 0.6347 - accuracy: 0.6614
# Epoch 90/100
#  - 1s - loss: 0.6351 - accuracy: 0.6607
# Epoch 91/100
#  - 1s - loss: 0.6350 - accuracy: 0.6594
# Epoch 92/100
#  - 1s - loss: 0.6353 - accuracy: 0.6608
# Epoch 93/100
#  - 1s - loss: 0.6343 - accuracy: 0.6609
# Epoch 94/100
#  - 1s - loss: 0.6350 - accuracy: 0.6603
# Epoch 95/100
#  - 1s - loss: 0.6354 - accuracy: 0.6607
# Epoch 96/100
#  - 1s - loss: 0.6348 - accuracy: 0.6611
# Epoch 97/100
#  - 1s - loss: 0.6347 - accuracy: 0.6609
# Epoch 98/100
#  - 1s - loss: 0.6345 - accuracy: 0.6601
# Epoch 99/100
#  - 1s - loss: 0.6351 - accuracy: 0.6598
# Epoch 100/100
#  - 1s - loss: 0.6346 - accuracy: 0.6608
# Deep Neural Network - Loss: 0.63438713915965, Accuracy: 0.6633684635162354

# %%
# save
save_model(model)
