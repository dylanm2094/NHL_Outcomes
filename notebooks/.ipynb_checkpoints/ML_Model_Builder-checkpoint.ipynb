# %%
import pandas as pd
from keras.models import Sequential, model_from_json
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv("final_df.csv")
cols = [0]
df.drop(df.columns[cols],axis=1,inplace=True)
df
# Out:
#        Home   ML  Puck Line     PL  Line Mvmt  net_goals  Win  Win_PL
# 0         0 -105        1.5 -305.0          0          0    1       1
# 1         1 -115       -1.5  250.0          0          0    0       0
# 2         0  165        1.5 -180.0          0          0    0       1
# 3         1 -185       -1.5  155.0        -10          0    1       0
# 4         0  130        1.5 -240.0        -29          0    1       1
# ...     ...  ...        ...    ...        ...        ...  ...     ...
# 13325     1 -160       -1.5  176.0          5        164    0       0
# 13326     0  105        1.5 -280.0         -5        163    1       1
# 13327     1 -115       -1.5  230.0         -5        118    0       0
# 13328     0  155        1.5 -183.0         -4        114    1       1
# 13329     1 -170       -1.5  159.0         -5        167    0       0
#
# [13330 rows x 8 columns]

# %%
target = df["Win_PL"]
target_names = ["loss", "win"]

# %%
data = df.drop(columns=['Win', 'Win_PL'],axis=1)
feature_names = data.columns

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.3, random_state=42)

# %%
y_train_categorical = to_categorical(y_train)
y_test_categorical = to_categorical(y_test)

# %%
def build_model():
    # create model
    model = Sequential()
    model.add(Dense(units=18, activation='relu', input_dim=6))
    model.add(Dense(units=9, activation='relu'))
    model.add(Dense(units=2, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

def save_model(model):
    # saving model
    json_model = model.to_json()
    open('model_architecture.json', 'w').write(json_model)
    # saving weights
    model.save_weights('model_weights.h5', overwrite=True)

def load_model():
    # loading model
    model = model_from_json(open('model_architecture.json').read())
    model.load_weights('model_weights.h5')
    model.compile(loss='categorical_crossentropy', optimizer='adam')
    return model

# %%
# build
model = build_model()
model.fit(X_train, y_train_categorical, epochs=50, shuffle=True, verbose=2)
model_loss, model_accuracy = model.evaluate(X_test, y_test_categorical, verbose=2)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")

# save
save_model(model)

# load
#model = load_model()

# predictions
# predictions = model.predict_classes(X_test, verbose=2)
# print(predictions)
# # reverse encoding
# for pred in predictions:
#     print(labels[pred])
# Out:
# Epoch 1/50
#  - 1s - loss: 2.3362 - accuracy: 0.5733
# Epoch 2/50
#  - 0s - loss: 0.8112 - accuracy: 0.6024
# Epoch 3/50
#  - 0s - loss: 0.7257 - accuracy: 0.6192
# Epoch 4/50
#  - 0s - loss: 0.6967 - accuracy: 0.6332
# Epoch 5/50
#  - 0s - loss: 0.6745 - accuracy: 0.6361
# Epoch 6/50
#  - 0s - loss: 0.6668 - accuracy: 0.6508
# Epoch 7/50
#  - 0s - loss: 0.6560 - accuracy: 0.6546
# Epoch 8/50
#  - 1s - loss: 0.6450 - accuracy: 0.6605
# Epoch 9/50
#  - 1s - loss: 0.6510 - accuracy: 0.6558
# Epoch 10/50
#  - 0s - loss: 0.6431 - accuracy: 0.6631
# Epoch 11/50
#  - 0s - loss: 0.6476 - accuracy: 0.6596
# Epoch 12/50
#  - 0s - loss: 0.6405 - accuracy: 0.6645
# Epoch 13/50
#  - 0s - loss: 0.6417 - accuracy: 0.6634
# Epoch 14/50
#  - 0s - loss: 0.6405 - accuracy: 0.6640
# Epoch 15/50
#  - 0s - loss: 0.6385 - accuracy: 0.6661
# Epoch 16/50
#  - 0s - loss: 0.6383 - accuracy: 0.6678
# Epoch 17/50
#  - 0s - loss: 0.6349 - accuracy: 0.6672
# Epoch 18/50
#  - 0s - loss: 0.6383 - accuracy: 0.6650
# Epoch 19/50
#  - 0s - loss: 0.6355 - accuracy: 0.6678
# Epoch 20/50
#  - 0s - loss: 0.6361 - accuracy: 0.6662
# Epoch 21/50
#  - 0s - loss: 0.6358 - accuracy: 0.6661
# Epoch 22/50
#  - 1s - loss: 0.6339 - accuracy: 0.6681
# Epoch 23/50
#  - 0s - loss: 0.6352 - accuracy: 0.6678
# Epoch 24/50
#  - 0s - loss: 0.6339 - accuracy: 0.6667
# Epoch 25/50
#  - 0s - loss: 0.6332 - accuracy: 0.6677
# Epoch 26/50
#  - 1s - loss: 0.6355 - accuracy: 0.6680
# Epoch 27/50
#  - 0s - loss: 0.6350 - accuracy: 0.6675
# Epoch 28/50
#  - 0s - loss: 0.6335 - accuracy: 0.6676
# Epoch 29/50
#  - 0s - loss: 0.6321 - accuracy: 0.6680
# Epoch 30/50
#  - 1s - loss: 0.6329 - accuracy: 0.6679
# Epoch 31/50
#  - 1s - loss: 0.6329 - accuracy: 0.6670
# Epoch 32/50
#  - 1s - loss: 0.6329 - accuracy: 0.6672
# Epoch 33/50
#  - 0s - loss: 0.6334 - accuracy: 0.6673
# Epoch 34/50
#  - 0s - loss: 0.6323 - accuracy: 0.6680
# Epoch 35/50
#  - 0s - loss: 0.6328 - accuracy: 0.6675
# Epoch 36/50
#  - 0s - loss: 0.6336 - accuracy: 0.6670
# Epoch 37/50
#  - 1s - loss: 0.6324 - accuracy: 0.6671
# Epoch 38/50
#  - 0s - loss: 0.6320 - accuracy: 0.6687
# Epoch 39/50
#  - 0s - loss: 0.6321 - accuracy: 0.6677
# Epoch 40/50
#  - 0s - loss: 0.6320 - accuracy: 0.6691
# Epoch 41/50
#  - 0s - loss: 0.6326 - accuracy: 0.6677
# Epoch 42/50
#  - 0s - loss: 0.6319 - accuracy: 0.6683
# Epoch 43/50
#  - 0s - loss: 0.6322 - accuracy: 0.6680
# Epoch 44/50
#  - 0s - loss: 0.6319 - accuracy: 0.6679
# Epoch 45/50
#  - 0s - loss: 0.6326 - accuracy: 0.6672
# Epoch 46/50
#  - 0s - loss: 0.6315 - accuracy: 0.6685
# Epoch 47/50
#  - 0s - loss: 0.6331 - accuracy: 0.6686
# Epoch 48/50
#  - 0s - loss: 0.6317 - accuracy: 0.6684
# Epoch 49/50
#  - 1s - loss: 0.6317 - accuracy: 0.6686
# Epoch 50/50
#  - 1s - loss: 0.6312 - accuracy: 0.6685
# Deep Neural Network - Loss: 0.6376142160509133, Accuracy: 0.6604151129722595
