# %%
import pandas as pd
from keras.models import Sequential, model_from_json
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv("final_df.csv")
cols = [0]
df.drop(df.columns[cols],axis=1,inplace=True)
df
# Out:
#        Home   ML  Puck Line     PL  Line Mvmt  net_goals  Win  Win_PL
# 0         0 -105        1.5 -305.0          0          0    1       1
# 1         1 -115       -1.5  250.0          0          0    0       0
# 2         0  165        1.5 -180.0          0          0    0       1
# 3         1 -185       -1.5  155.0        -10          0    1       0
# 4         0  130        1.5 -240.0        -29          0    1       1
# ...     ...  ...        ...    ...        ...        ...  ...     ...
# 13325     1 -160       -1.5  176.0          5        164    0       0
# 13326     0  105        1.5 -280.0         -5        163    1       1
# 13327     1 -115       -1.5  230.0         -5        118    0       0
# 13328     0  155        1.5 -183.0         -4        114    1       1
# 13329     1 -170       -1.5  159.0         -5        167    0       0
#
# [13330 rows x 8 columns]

# %%
target = df["Win"]
target_names = ["loss", "win"]

# %%
data = df.drop(columns=['Win', 'Win_PL'],axis=1)
feature_names = data.columns

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.3, random_state=42)

# %%
y_train_categorical = to_categorical(y_train)
y_test_categorical = to_categorical(y_test)

# %%
def build_model():
    # create model
    model = Sequential()
    model.add(Dense(units=18, activation='relu', input_dim=6))
    model.add(Dense(units=9, activation='relu'))
    model.add(Dense(units=2, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

def save_model(model):
    # saving model
    json_model = model.to_json()
    open('ML_model_architecture.json', 'w').write(json_model)
    # saving weights
    model.save_weights('ML_model_weights.h5', overwrite=True)

# %%
# build
model = build_model()
model.fit(X_train, y_train_categorical, epochs=200, shuffle=True, verbose=2)
model_loss, model_accuracy = model.evaluate(X_test, y_test_categorical, verbose=2)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")

# save
save_model(model)
# Out:
# Epoch 1/200
#  - 1s - loss: 2.4006 - accuracy: 0.5095
# Epoch 2/200
#  - 1s - loss: 0.8824 - accuracy: 0.5396
# Epoch 3/200
#  - 0s - loss: 0.7965 - accuracy: 0.5410
# Epoch 4/200
#  - 0s - loss: 0.7500 - accuracy: 0.5506
# Epoch 5/200
#  - 1s - loss: 0.7330 - accuracy: 0.5532
# Epoch 6/200
#  - 0s - loss: 0.7264 - accuracy: 0.5595
# Epoch 7/200
#  - 0s - loss: 0.7195 - accuracy: 0.5607
# Epoch 8/200
#  - 0s - loss: 0.7057 - accuracy: 0.5600
# Epoch 9/200
#  - 0s - loss: 0.7105 - accuracy: 0.5606
# Epoch 10/200
#  - 0s - loss: 0.7007 - accuracy: 0.5571
# Epoch 11/200
#  - 0s - loss: 0.7004 - accuracy: 0.5652
# Epoch 12/200
#  - 0s - loss: 0.6990 - accuracy: 0.5590
# Epoch 13/200
#  - 1s - loss: 0.6960 - accuracy: 0.5641
# Epoch 14/200
#  - 1s - loss: 0.6929 - accuracy: 0.5690
# Epoch 15/200
#  - 1s - loss: 0.6972 - accuracy: 0.5578
# Epoch 16/200
#  - 1s - loss: 0.6912 - accuracy: 0.5654
# Epoch 17/200
#  - 0s - loss: 0.6891 - accuracy: 0.5645
# Epoch 18/200
# ...
