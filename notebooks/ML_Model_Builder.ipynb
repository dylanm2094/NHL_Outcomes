# %%
import pandas as pd
from keras.models import Sequential, model_from_json
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv("final_df.csv")
cols = [0]
df.drop(df.columns[cols],axis=1,inplace=True)
df
# Out:
#        Home   ML     PL  Line Mvmt  net_goals  season_wins  Win  Win_PL
# 0         0 -105 -305.0          0          0            0    1       1
# 1         1 -115  250.0          0          0            0    0       0
# 2         0  165 -180.0          0          0            0    0       1
# 3         1 -185  155.0        -10          0            0    1       0
# 4         0  130 -240.0        -29          0            0    1       1
# ...     ...  ...    ...        ...        ...          ...  ...     ...
# 15489     1 -146  170.0        -19         45           41    1       0
# 15490     0  145 -180.0         -5        -51           25    0       1
# 15491     1 -160  160.0          0        -35           28    1       0
# 15492     0 -200  115.0         23         30           41    1       1
# 15493     1  180 -135.0        -28        -37           29    0       0
#
# [15494 rows x 8 columns]

# %%
target = df["Win"]
target_names = ["loss", "win"]

# %%
data = df.drop(columns=['Win', 'Win_PL'],axis=1)
feature_names = data.columns

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.3, random_state=42)

# %%
y_train_categorical = to_categorical(y_train)
y_test_categorical = to_categorical(y_test)

# %%
def build_model():
    # create model
    model = Sequential()
    model.add(Dense(units=18, activation='relu', input_dim=6))
    model.add(Dense(units=9, activation='relu'))
    model.add(Dense(units=2, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

def save_model(model):
    # saving model
    json_model = model.to_json()
    open('ML_model_architecture.json', 'w').write(json_model)
    # saving weights
    model.save_weights('ML_model_weights.h5', overwrite=True)

# %%
# build
model = build_model()
model.fit(X_train, y_train_categorical, epochs=100, shuffle=True, verbose=2)
model_loss, model_accuracy = model.evaluate(X_test, y_test_categorical, verbose=2)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")

# save
save_model(model)
# Out:
# Epoch 1/100
#  - 1s - loss: 6.5949 - accuracy: 0.5185
# Epoch 2/100
#  - 1s - loss: 1.0975 - accuracy: 0.5325
# Epoch 3/100
#  - 1s - loss: 0.8646 - accuracy: 0.5422
# Epoch 4/100
#  - 1s - loss: 0.8372 - accuracy: 0.5369
# Epoch 5/100
#  - 1s - loss: 0.8001 - accuracy: 0.5443
# Epoch 6/100
#  - 1s - loss: 0.8129 - accuracy: 0.5432
# Epoch 7/100
#  - 1s - loss: 0.7868 - accuracy: 0.5490
# Epoch 8/100
#  - 1s - loss: 0.7726 - accuracy: 0.5485
# Epoch 9/100
#  - 1s - loss: 0.7591 - accuracy: 0.5482
# Epoch 10/100
#  - 1s - loss: 0.7602 - accuracy: 0.5435
# Epoch 11/100
#  - 1s - loss: 0.7616 - accuracy: 0.5509
# Epoch 12/100
#  - 1s - loss: 0.7409 - accuracy: 0.5565
# Epoch 13/100
#  - 1s - loss: 0.7444 - accuracy: 0.5512
# Epoch 14/100
#  - 1s - loss: 0.7548 - accuracy: 0.5425
# Epoch 15/100
#  - 1s - loss: 0.7498 - accuracy: 0.5539
# Epoch 16/100
#  - 1s - loss: 0.7424 - accuracy: 0.5547
# Epoch 17/100
#  - 1s - loss: 0.7519 - accuracy: 0.5528
# Epoch 18/100
#  - 1s - loss: 0.7366 - accuracy: 0.5463
# Epoch 19/100
#  - 1s - loss: 0.7276 - accuracy: 0.5538
# Epoch 20/100
#  - 1s - loss: 0.7301 - accuracy: 0.5537
# Epoch 21/100
#  - 1s - loss: 0.7320 - accuracy: 0.5499
# Epoch 22/100
#  - 1s - loss: 0.7354 - accuracy: 0.5462
# Epoch 23/100
#  - 1s - loss: 0.7278 - accuracy: 0.5416
# Epoch 24/100
#  - 1s - loss: 0.7249 - accuracy: 0.5488
# Epoch 25/100
#  - 1s - loss: 0.7404 - accuracy: 0.5459
# Epoch 26/100
#  - 1s - loss: 0.7227 - accuracy: 0.5410
# Epoch 27/100
#  - 1s - loss: 0.7285 - accuracy: 0.5494
# Epoch 28/100
#  - 1s - loss: 0.7108 - accuracy: 0.5547
# Epoch 29/100
#  - 1s - loss: 0.7244 - accuracy: 0.5487
# Epoch 30/100
#  - 1s - loss: 0.7113 - accuracy: 0.5590
# Epoch 31/100
#  - 1s - loss: 0.7093 - accuracy: 0.5588
# Epoch 32/100
#  - 1s - loss: 0.7124 - accuracy: 0.5532
# Epoch 33/100
#  - 1s - loss: 0.7148 - accuracy: 0.5572
# Epoch 34/100
#  - 1s - loss: 0.7097 - accuracy: 0.5573
# Epoch 35/100
#  - 1s - loss: 0.7113 - accuracy: 0.5563
# Epoch 36/100
#  - 1s - loss: 0.7142 - accuracy: 0.5555
# Epoch 37/100
#  - 1s - loss: 0.7142 - accuracy: 0.5539
# Epoch 38/100
#  - 1s - loss: 0.7095 - accuracy: 0.5599
# Epoch 39/100
#  - 1s - loss: 0.7127 - accuracy: 0.5506
# Epoch 40/100
#  - 1s - loss: 0.7096 - accuracy: 0.5566
# Epoch 41/100
#  - 1s - loss: 0.7006 - accuracy: 0.5652
# Epoch 42/100
#  - 1s - loss: 0.7001 - accuracy: 0.5623
# Epoch 43/100
#  - 1s - loss: 0.7029 - accuracy: 0.5675
# Epoch 44/100
#  - 1s - loss: 0.7052 - accuracy: 0.5533
# Epoch 45/100
#  - 1s - loss: 0.7009 - accuracy: 0.5569
# Epoch 46/100
#  - 1s - loss: 0.7037 - accuracy: 0.5614
# Epoch 47/100
#  - 1s - loss: 0.6983 - accuracy: 0.5635
# Epoch 48/100
#  - 1s - loss: 0.6953 - accuracy: 0.5603
# Epoch 49/100
#  - 1s - loss: 0.6972 - accuracy: 0.5575
# Epoch 50/100
#  - 1s - loss: 0.6995 - accuracy: 0.5613
# Epoch 51/100
#  - 1s - loss: 0.6928 - accuracy: 0.5658
# Epoch 52/100
#  - 1s - loss: 0.6940 - accuracy: 0.5627
# Epoch 53/100
#  - 1s - loss: 0.6942 - accuracy: 0.5654
# Epoch 54/100
#  - 1s - loss: 0.6880 - accuracy: 0.5738
# Epoch 55/100
#  - 1s - loss: 0.6910 - accuracy: 0.5658
# Epoch 56/100
#  - 1s - loss: 0.6919 - accuracy: 0.5633
# Epoch 57/100
#  - 1s - loss: 0.6905 - accuracy: 0.5618
# Epoch 58/100
#  - 1s - loss: 0.6855 - accuracy: 0.5738
# Epoch 59/100
#  - 1s - loss: 0.6850 - accuracy: 0.5776
# Epoch 60/100
#  - 1s - loss: 0.6881 - accuracy: 0.5637
# Epoch 61/100
#  - 1s - loss: 0.6814 - accuracy: 0.5769
# Epoch 62/100
#  - 1s - loss: 0.6842 - accuracy: 0.5725
# Epoch 63/100
#  - 1s - loss: 0.6805 - accuracy: 0.5756
# Epoch 64/100
#  - 1s - loss: 0.6865 - accuracy: 0.5720
# Epoch 65/100
#  - 1s - loss: 0.6816 - accuracy: 0.5743
# Epoch 66/100
#  - 1s - loss: 0.6802 - accuracy: 0.5731
# Epoch 67/100
#  - 1s - loss: 0.6799 - accuracy: 0.5769
# Epoch 68/100
#  - 1s - loss: 0.6805 - accuracy: 0.5781
# Epoch 69/100
#  - 1s - loss: 0.6784 - accuracy: 0.5773
# Epoch 70/100
#  - 1s - loss: 0.6799 - accuracy: 0.5791
# Epoch 71/100
#  - 1s - loss: 0.6789 - accuracy: 0.5742
# Epoch 72/100
#  - 1s - loss: 0.6781 - accuracy: 0.5763
# Epoch 73/100
#  - 1s - loss: 0.6751 - accuracy: 0.5812
# Epoch 74/100
#  - 1s - loss: 0.6755 - accuracy: 0.5823
# Epoch 75/100
#  - 1s - loss: 0.6761 - accuracy: 0.5812
# Epoch 76/100
#  - 1s - loss: 0.6752 - accuracy: 0.5780
# Epoch 77/100
#  - 1s - loss: 0.6749 - accuracy: 0.5837
# Epoch 78/100
#  - 1s - loss: 0.6731 - accuracy: 0.5857
# Epoch 79/100
#  - 1s - loss: 0.6745 - accuracy: 0.5803
# Epoch 80/100
#  - 1s - loss: 0.6735 - accuracy: 0.5828
# Epoch 81/100
#  - 1s - loss: 0.6739 - accuracy: 0.5812
# Epoch 82/100
#  - 1s - loss: 0.6729 - accuracy: 0.5830
# Epoch 83/100
#  - 1s - loss: 0.6741 - accuracy: 0.5805
# Epoch 84/100
#  - 1s - loss: 0.6735 - accuracy: 0.5835
# Epoch 85/100
#  - 1s - loss: 0.6729 - accuracy: 0.5841
# Epoch 86/100
#  - 1s - loss: 0.6735 - accuracy: 0.5824
# Epoch 87/100
#  - 1s - loss: 0.6729 - accuracy: 0.5846
# Epoch 88/100
#  - 1s - loss: 0.6729 - accuracy: 0.5836
# Epoch 89/100
#  - 1s - loss: 0.6727 - accuracy: 0.5844
# Epoch 90/100
#  - 1s - loss: 0.6725 - accuracy: 0.5836
# Epoch 91/100
#  - 1s - loss: 0.6728 - accuracy: 0.5870
# Epoch 92/100
#  - 1s - loss: 0.6726 - accuracy: 0.5844
# Epoch 93/100
#  - 1s - loss: 0.6729 - accuracy: 0.5845
# Epoch 94/100
#  - 1s - loss: 0.6725 - accuracy: 0.5855
# Epoch 95/100
#  - 1s - loss: 0.6719 - accuracy: 0.5862
# Epoch 96/100
#  - 1s - loss: 0.6724 - accuracy: 0.5852
# Epoch 97/100
#  - 1s - loss: 0.6724 - accuracy: 0.5845
# Epoch 98/100
#  - 1s - loss: 0.6722 - accuracy: 0.5821
# Epoch 99/100
#  - 1s - loss: 0.6719 - accuracy: 0.5829
# Epoch 100/100
#  - 1s - loss: 0.6729 - accuracy: 0.5828
# Deep Neural Network - Loss: 0.676247128801311, Accuracy: 0.5818455815315247

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=210,criterion='entropy')
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.5371047537104754
